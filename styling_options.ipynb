# %% [markdown]
# # Jupyter Notebook styling options

# %% [markdown]
# ## Overview

# %% [markdown]
# * [Horizontal line](#hr)
# * [Coloured boxes](#boxes)
# * [Anchor links](#anchors)
# * [Embedding images](#images)

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='hr'></a>Horizontal line

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='boxes'></a>Coloured boxes

# %% [markdown]
# <div class='alert alert-block alert-info'>
# This is a blue box
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# This is a blue box
# </div>

# %% [markdown]
# <div class='alert alert-block alert-success'>
# This is a green box
# </div>

# %% [markdown]
# <div class='alert alert-block alert-danger'>
# This is a red box
# </div>

# %% [markdown]
# <div class='alert alert-block alert-warning'>
# This is an orange box
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='anchors'></a>Anchor links

# %% [markdown]
# * [Heading1](#heading1)
# * [Heading2](#heading2)

# %% [markdown]
# ### <a id='heading1'></a>Heading 1

# %% [markdown]
# ### <a id='heading2'></a>Heading 2

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='images'></a>Embedding images

# %% [markdown]
# ![image.png](attachment:155bda79-483c-408c-abcf-291543afcedd.png)]
